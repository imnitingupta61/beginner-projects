# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("C:\\Users\\NITIN GUPTA\\HR_data.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head(10).T
# Out:
#                                         0                       1  \
# Age                                    41                      49
# Attrition                             Yes                      No
# BusinessTravel              Travel_Rarely       Travel_Frequently
# DailyRate                            1102                     279
# Department                          Sales  Research & Development
# DistanceFromHome                        1                       8
# Education                               2                       1
# EducationField              Life Sciences           Life Sciences
# EmployeeCount                           1                       1
# EmployeeNumber                          1                       2
# EnvironmentSatisfaction                 2                       3
# Gender                             Female                    Male
# HourlyRate                             94                      61
# ...

# %% [markdown]
# # Checking for Null valuse

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per above visualization no null value present

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
sns.countplot(x = "Attrition", data= df)
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# As per above visualization Attrition present in 237 rows and no attrition is 1233 rows

# %%
sns.countplot(x = "BusinessTravel", data= df)
df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %% [markdown]
# As per above visualization employee who not travels are 150 who are rarely travel are 1043 and frequently travel are 277

# %%
sns.countplot(x = "Department", data= df)
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %% [markdown]
# As per above visualization 961 employees are from Research & Development department, 446 are from sales department and 63 are from Human Resourse department

# %%
sns.countplot(x = "EducationField", data= df)
df['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %% [markdown]
# As per above visualization 606 employees are from life science field, 464 are from Medical fiels, 159 are from Marketing Fiels, 132 have technical degree , 82 are from other field and 27 are from HR field

# %%
sns.countplot(x = "Gender", data= df)
df['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %% [markdown]
# As per above visualization 882 are male employees and 588 are female employees

# %%
sns.countplot(x = "JobRole", data= df)
df['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %% [markdown]
# As per above visualization 326 employees have Sales executive Job role, 292 have Research Scientist, 259 has Laboratory Technician, 145 have Manufacturing Director, 131 have healthcare Representative, 102 have manager, 83 have Sales Representative, 80 hace research Director and 52 have HumanResource Job Roles

# %%
sns.countplot(x = "MaritalStatus", data= df)
df['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# As per above visualization 673 employees are Married, 470 are single and 327 are divorced employees

# %%
sns.countplot(x = "Over18", data= df)
df['Over18'].value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %% [markdown]
# As per above visualization and data all the values in Yes form so need to be dropped as constant

# %%
sns.countplot(x = "OverTime", data= df)
df['OverTime'].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %% [markdown]
# As per above visualization 416 emploees do over time and 1054 are not doing overtime.

# %% [markdown]
# # Checking Distrivution of continuous columns

# %%
sns.distplot(df['Age'], kde= True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['DailyRate'], kde= True)
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='Density'>

# %%
sns.distplot(df['DistanceFromHome'], kde= True)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Density'>

# %%
sns.distplot(df['Education'], kde= True)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Density'>

# %%
sns.distplot(df['EmployeeCount'], kde= True)
# Out:
# <AxesSubplot:xlabel='EmployeeCount', ylabel='Density'>

# %% [markdown]
# As per above visualization of Employeecount which is constant need to be dropped

# %%
sns.distplot(df['StandardHours'], kde= True)
# Out:
# <AxesSubplot:xlabel='StandardHours', ylabel='Density'>

# %% [markdown]
# As per above visualization of StanddardHours which is constant need to be dropped

# %%
df.drop(['EmployeeCount', 'Over18', 'StandardHours', 'EmployeeNumber'], axis = 1, inplace = True)

# %%
df.describe().T
# Out:
#                            count          mean          std     min     25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.0
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.0
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.0
# Education                 1470.0      2.912925     1.024165     1.0     2.0
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.0
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.0
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.0
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.0
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.0
# MonthlyIncome             1470.0   6502.931293  4707.956783  1009.0  2911.0
# MonthlyRate               1470.0  14313.103401  7117.786044  2094.0  8047.0
# ...

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# ...

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(14,14))
sns.heatmap(df.corr(), annot = True, fmt= '.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per above visualization TotalWorkingYears is highly postive coorelated value 0.68

# %% [markdown]
# # Numerical Features

# %%
nu_data = df.select_dtypes(exclude=['object'])
nu_data
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0      41       1102                 1          2                        2
# 1      49        279                 8          1                        3
# 2      37       1373                 2          2                        4
# 3      33       1392                 3          4                        4
# 4      27        591                 2          1                        1
# ...   ...        ...               ...        ...                      ...
# 1465   36        884                23          2                        3
# 1466   39        613                 6          1                        4
# 1467   27        155                 4          3                        2
# 1468   49       1023                 2          3                        4
# 1469   34        628                 8          3                        2
#
# ...

# %%
nu_data.hist(figsize= (30,40), bins =100, xlabelsize = 10, ylabelsize = 10)
plt.show()

# %%
for i in nu_data:
    sns.barplot(y = nu_data[i], x = df['Attrition'])
    plt.show()

# %% [markdown]
# # Checking Outliers

# %%
for i in nu_data:
    plt.boxplot(nu_data[i], labels= [i])
    plt.show()

# %% [markdown]
# As per above visualization 'MonthlyIncome','NumCompaniesWorked', 'TotalWorkingYears', 'YearsInCurrentRole',
#      'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager having outliers but actual values so no need to remove

# %%
df.nunique().sort_values()
# Out:
# Attrition                      2
# PerformanceRating              2
# OverTime                       2
# Gender                         2
# MaritalStatus                  3
# BusinessTravel                 3
# Department                     3
# RelationshipSatisfaction       4
# JobSatisfaction                4
# JobInvolvement                 4
# StockOptionLevel               4
# WorkLifeBalance                4
# EnvironmentSatisfaction        4
# JobLevel                       5
# Education                      5
# EducationField                 6
# TrainingTimesLastYear          7
# JobRole                        9
# NumCompaniesWorked            10
# PercentSalaryHike             15
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# YearsInCurrentRole            19
# DistanceFromHome              29
# YearsAtCompany                37
# TotalWorkingYears             40
# Age                           43
# HourlyRate                    71
# ...

# %% [markdown]
# All attributes with 4,5 and 7 unique values are numeric and don't need any modification
# Dropping HourlyRate, DailyRate, MonthlyRate and MonthlyIncome as they are ambiguous.

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i]= enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot = True, fmt= '.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per above visualization Overtime is highly coorelated with Attrition 0.25

# %%
df = df.drop('Age', axis=1)
df
# Out:
#       Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0             1               2       1102           2                 1
# 1             0               1        279           1                 8
# 2             1               2       1373           1                 2
# 3             0               1       1392           1                 3
# 4             0               2        591           1                 2
# ...         ...             ...        ...         ...               ...
# 1465          0               1        884           1                23
# 1466          0               2        613           1                 6
# 1467          0               2        155           1                 4
# 1468          0               1       1023           2                 2
# 1469          0               2        628           1                 8
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %% [markdown]
# # Split the Data

# %%
x = df.iloc[:,1:]
y= df.iloc[:,0]

# %%
x.shape
# Out:
# (1470, 29)

# %%
y.shape
# Out:
# (1470,)

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size= .22, random_state=42)
estimator = []
estimator.append(('LR',LogisticRegression()))
estimator.append(('KNN',KNeighborsClassifier()))
estimator.append(('SV',SVC()))
estimator.append(('DT',DecisionTreeClassifier()))
estimator.append(('RF',RandomForestClassifier(n_estimators=100, random_state=42)))
estimator
# Out:
# [('LR', LogisticRegression()),
#  ('KNN', KNeighborsClassifier()),
#  ('SV', SVC()),
#  ('DT', DecisionTreeClassifier()),
#  ('RF', RandomForestClassifier(random_state=42))]

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
vot_hard = VotingClassifier(estimators= estimator, voting= 'hard')
vot_hard.fit(xtrain,ytrain)
pred = vot_hard.predict(xtest)
print("Accuracy Score", accuracy_score(ytest,pred))
print("Confusion Metrics", confusion_matrix(ytest,pred))
print("Classification_report", classification_report(ytest,pred))
# Out:
# Accuracy Score 0.8734567901234568
# Confusion Metrics [[283   0]
#  [ 41   0]]
# Classification_report               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       283
#            1       0.00      0.00      0.00        41
#
#     accuracy                           0.87       324
#    macro avg       0.44      0.50      0.47       324
# weighted avg       0.76      0.87      0.81       324

# %%
LR = LogisticRegression()
KNN = KNeighborsClassifier()
SV = SVC()
DT = DecisionTreeClassifier()
RF = RandomForestClassifier(n_estimators=100, random_state=42)
mod = [LR, KNN, SV, DT, RF]

mod
# Out:
# [LogisticRegression(),
#  KNeighborsClassifier(),
#  SVC(),
#  DecisionTreeClassifier(),
#  RandomForestClassifier(random_state=42)]

# %%
for i in mod:
    xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size= .22, random_state=42)
    i.fit(xtrain,ytrain)
    pred = i.predict(xtest)
    print("Accuracy Score", accuracy_score(ytest,pred))
    print("Confusion Metrics", confusion_matrix(ytest,pred))
    print("Classification_report", classification_report(ytest,pred))
# Out:
# Accuracy Score 0.8549382716049383
# Confusion Metrics [[274   9]
#  [ 38   3]]
# Classification_report               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       283
#            1       0.25      0.07      0.11        41
#
#     accuracy                           0.85       324
#    macro avg       0.56      0.52      0.52       324
# weighted avg       0.80      0.85      0.82       324
#
# Accuracy Score 0.8395061728395061
# Confusion Metrics [[267  16]
#  [ 36   5]]
# Classification_report               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91       283
#            1       0.24      0.12      0.16        41
#
#     accuracy                           0.84       324
#    macro avg       0.56      0.53      0.54       324
# weighted avg       0.80      0.84      0.82       324
#
# Accuracy Score 0.8734567901234568
# Confusion Metrics [[283   0]
#  [ 41   0]]
# ...

# %% [markdown]
# As per above result we consider Random forest gives teh best accuracy

# %% [markdown]
# # Now we can check with various parameter using Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
model = RandomForestClassifier()

# %%
param_grid = {'n_estimators': [10,20,50,100],'criterion' :['entropy'], 'random_state' : [0,20,40,42]}

# %%
grid = GridSearchCV(estimator = model, param_grid = param_grid)

# %%
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['entropy'],
#                          'n_estimators': [10, 20, 50, 100],
#                          'random_state': [0, 20, 40, 42]})

# %%
print(grid.best_score_)
print(grid.best_estimator_)
print(grid.best_params_)
# Out:
# 0.8560205050313272
# RandomForestClassifier(criterion='entropy', n_estimators=50, random_state=42)
# {'criterion': 'entropy', 'n_estimators': 50, 'random_state': 42}

# %% [markdown]
# As per Grid Search CV we found the best accuracy when criterion='entropy',n_estimators=500, random_state= 42

# %%
RFC = RandomForestClassifier(criterion='entropy', random_state= 42,n_estimators=50)

# %%
RFC.fit(xtrain,ytrain)
pred = RFC.predict(xtest)
print("Accuracy Score", accuracy_score(ytest,pred))
print("Confusion Metrics", confusion_matrix(ytest,pred))
print("Classification_report", classification_report(ytest,pred))
# Out:
# Accuracy Score 0.8703703703703703
# Confusion Metrics [[280   3]
#  [ 39   2]]
# Classification_report               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       283
#            1       0.40      0.05      0.09        41
#
#     accuracy                           0.87       324
#    macro avg       0.64      0.52      0.51       324
# weighted avg       0.82      0.87      0.82       324

# %% [markdown]
# # Cross validation score for Random Forest Classifier

# %%
from sklearn.model_selection import cross_val_score
for i in range (2,10):
    score= cross_val_score(RF,x,y,cv=i)
    print("At cv value at", i,"the cv score is",score)
    print(score.mean())
    print(score.std())
# Out:
# At cv value at 2 the cv score is [0.85578231 0.85578231]
# 0.85578231292517
# 0.0
# At cv value at 3 the cv score is [0.85714286 0.85918367 0.85918367]
# 0.8585034013605441
# 0.0009620500424306884
# At cv value at 4 the cv score is [0.86413043 0.86684783 0.84741144 0.86103542]
# 0.8598562818386446
# 0.007473527145830058
# At cv value at 5 the cv score is [0.85714286 0.86054422 0.86054422 0.86394558 0.85714286]
# 0.8598639455782312
# 0.002545345161070711
# At cv value at 6 the cv score is [0.83673469 0.86530612 0.86530612 0.84081633 0.85714286 0.85714286]
# 0.8537414965986394
# 0.01115729215432431
# At cv value at 7 the cv score is [0.86190476 0.85238095 0.85714286 0.88571429 0.85238095 0.85238095
#  0.85714286]
# 0.8598639455782312
# 0.011053113475695184
# At cv value at 8 the cv score is [0.86956522 0.85326087 0.8423913  0.86956522 0.8423913  0.86956522
#  0.85245902 0.86885246]
# 0.8585063257305774
# 0.011496805628052375
# ...

# %% [markdown]
# # AUC ROC CURVE

# %%
from sklearn.metrics import roc_curve,auc
fpr,tpr,thresholds = roc_curve(pred, ytest)
roc_auc=auc(fpr,tpr)

plt.figure()
plt.plot(fpr, tpr, color = "darkorange", lw =10, label ="ROC Curve (area= %0.2f)" %roc_auc)
plt.plot([0,1], [0,1], color= 'navy', lw =10, linestyle ='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristics")
plt.legend(loc ="lower right")
plt.show()

# %% [markdown]
# # Model Saving

# %%
import pickle
filename = "titanic_train.pkl"
pickle.dump(RF, open(filename, 'wb'))

# %% [markdown]
# # Conclusion

# %%
import numpy as np
a = np.array(ytest)
predicted =np.array(RFC.predict(xtrain))
df_com= pd.DataFrame({"Original":a, "Predicted":pred}, index =range(len(a)))
df_com
# Out:
#      Original  Predicted
# 0           0          0
# 1           0          0
# 2           1          0
# 3           0          0
# 4           0          0
# ..        ...        ...
# 319         0          0
# 320         0          0
# 321         0          0
# 322         0          0
# 323         0          0
#
# [324 rows x 2 columns]
