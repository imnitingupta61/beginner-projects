# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# As per above observations there is no null values in data

# %% [markdown]
# # Checking through visualisation

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per visualisation no null values is showing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# All the above data in form of int and float

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# As per describe data because the difference between min,25%,50%,75% & max is not equal. So skewness present in data.

# %% [markdown]
# # Checking Coorelation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot= True, linewidth=1, linecolor='white', fmt= '0.2f')
# Out:
# <AxesSubplot:>

# %% [raw]
# df.corr()

# %% [markdown]
# As per above visualialization we can see Runs Allowed, Earned Runs, Earned Run Average (ERA) are negative coorelation with win, SV(saves) has verh high positive coorelation with win- 0.67.

# %% [markdown]
# BB has second highest positive coorelation with wins: 0.48
# Shutouts has third highest positive coorelation with wins  : 0.47
# Runs and doubles has same coorelation with wins: 0.43
# Home runs has coorelation with wins: 0.31

# %%
plt.figure(figsize= (15,10))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='Grey')
plt.xlabel('Features', fontsize=20)
plt.ylabel('Columns with target names', fontsize=20)
plt.title('Correlation', fontsize=20)
plt.show()

# %% [markdown]
# As per above visualization ERA, RA, ER, 3B,SB,E,AB are negatively coorelated with target variable

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Keeping +/-0.50 range of skewness. The columns whose does not lie all are R, AB,2B,3B,BB,SO,RA,ER & ERA

# %%
df.hist(bins = 20, figsize= (10,10))
plt.show()

# %% [markdown]
# As per the above visualization the skewness is present in data

# %% [markdown]
# # Normal Distribution Curve

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.distplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %% [markdown]
# As per above visualization the data is left and right skewed so skewness is present in data

# %% [markdown]
# # Split the data in feature and target

# %%
x= df.iloc[:, 1:]
y= df.iloc[:,0]

# %%
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %% [markdown]
# # Transforming the data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x= power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 0.        ,  0.        ,  0.        ,  1.47768528,  1.03310301,
#         -0.76462586, -1.61091476, -2.56989562,  0.93970819, -0.66033096,
#         -0.49742469, -0.50089346, -0.35984364, -0.78957937,  1.546378  ,
#         -0.3349525 ],
#        [ 0.        ,  0.        ,  0.        ,  0.08426878,  1.2033202 ,
#         -0.15858141, -0.50274883,  0.13491294, -0.53969308,  0.17546536,
#          0.25797351,  0.26180619, -0.35984364,  0.25177537,  0.36044386,
#         -0.53221128],
#        [ 0.        ,  0.        ,  0.        ,  1.67078208, -0.16026987,
#         -0.68967629,  1.1282937 , -0.90125379,  0.2119555 , -0.67462053,
#         -0.74690639, -0.63645949,  1.99351257, -0.24539345, -0.6075936 ,
#         -1.34233137],
#        [ 0.        ,  0.        ,  0.        , -0.84859969, -0.36052064,
#         -0.8790486 , -1.18120722, -0.1896282 , -0.64256433,  0.18951225,
#          0.11357524,  0.06080381,  1.22010317, -0.51075929, -0.76445333,
#          0.67852361],
# ...

# %%
pd.DataFrame(x).skew()
# Out:
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3    -0.035315
# 4    -0.072933
# 5    -0.000065
# 6    -0.007760
# 7     0.041170
# 8    -0.010455
# 9    -0.008082
# 10   -0.001940
# 11    0.001746
# 12   -0.059785
# 13    0.006560
# 14    0.000836
# 15    0.063909
# dtype: float64

# %% [markdown]
# # Checking Outliers

# %%
collist = df.columns.values
ncol= 100
nrow = 15
plt.figure(figsize=(ncol,ncol))
for i in range(0, len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color='red', orient="h")
    plt.tight_layout()

# %% [markdown]
# As per the above visualization of boxplot we can see outliers in R, ERA, SHO & SV has less outliers and E has more outliers, W,AB,H,2B,3B,HR,BB,SO,SB,RA,ER,CG has no outliers

# %% [markdown]
# # Removing Outliers Taking an openion of data loss

# %%
from scipy.stats import zscore
import numpy as np
z = np.abs(zscore(df))
z.shape
# Out:
# (30, 17)

# %%
threshold =3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 1

# %%
z.iloc[5]
# Out:
# W      1.170814
# R      3.509647
# AB     0.104884
# H      1.361089
# 2B     1.869832
# 3B     1.391501
# HR     2.185047
# BB     1.798742
# SO     0.952796
# SB     0.200609
# RA     0.257184
# ER     0.389104
# ERA    0.350165
# CG     1.300442
# SHO    0.320914
# SV     1.171848
# E      0.461470
# Name: 5, dtype: float64

# %%
df_new = df[(z<3).all(axis=1)]
print("old Dataframe", df.shape)
print("new Dataframe", df_new.shape)
print("total_dropped_rows", df.shape[0]-df_new.shape[0])
# Out:
# old Dataframe (30, 17)
# new Dataframe (29, 17)
# total_dropped_rows 1

# %% [markdown]
# # Percentage Data Loss

# %%
loss_percent=(30-29)/30*100
print(loss_percent, "%")
# Out:
# 3.3333333333333335 %

# %% [markdown]
# Model with outlier is df & Model without outlier is df_new

# %%
x= df_new.iloc[:, 1:]
y= df_new.iloc[:,0]

# %%
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %% [markdown]
# # For scaling data using MIn Max scaler

# %%
from sklearn .preprocessing import MinMaxScaler
sc = MinMaxScaler()
feature= sc.fit_transform(x)

# %% [markdown]
# # Importing Model

# %%
import sklearn
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score

# %%
neigh = KNeighborsRegressor(n_neighbors=2)
dt = DecisionTreeRegressor()
rf= RandomForestRegressor(n_estimators=100, random_state=42)
ab= AdaBoostRegressor()
rd= Ridge()
mod = [neigh, dt, rf, ab, rd]
mod
# Out:
# [KNeighborsRegressor(n_neighbors=2),
#  DecisionTreeRegressor(),
#  RandomForestRegressor(random_state=42),
#  AdaBoostRegressor(),
#  Ridge()]

# %%
for j in mod:
    for i in range(0,100):
        xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size= 0.22, random_state=i)
        j.fit(xtrain,ytrain)
        pred_train = j.predict(xtrain)
        pred_test= j.predict(xtest)

        print(f"For Model {j} At random state {i}, the training accuracy is: {r2_score(ytrain,pred_train)}")
        print(f"For Model {j} At random state {i}, the testing accuracy is: {r2_score(ytest,pred_test)}")
        print('\n')
# Out:
# For Model KNeighborsRegressor(n_neighbors=2) At random state 0, the training accuracy is: 0.847573788510652
# For Model KNeighborsRegressor(n_neighbors=2) At random state 0, the testing accuracy is: 0.030336257309941494
#
#
# For Model KNeighborsRegressor(n_neighbors=2) At random state 1, the training accuracy is: 0.8225589320680826
# For Model KNeighborsRegressor(n_neighbors=2) At random state 1, the testing accuracy is: 0.5458823529411765
#
#
# For Model KNeighborsRegressor(n_neighbors=2) At random state 2, the training accuracy is: 0.7714859476247076
# For Model KNeighborsRegressor(n_neighbors=2) At random state 2, the testing accuracy is: 0.016880260137719816
#
#
# For Model KNeighborsRegressor(n_neighbors=2) At random state 3, the training accuracy is: 0.8060887256847955
# For Model KNeighborsRegressor(n_neighbors=2) At random state 3, the testing accuracy is: 0.6309278350515464
#
#
# ...

# %% [markdown]
# As per above model we have get as per r2 score the best model Ridge regression at random state 27 & 73

# %%
print("Mean Squared error", mean_squared_error(ytest,pred_test))
print("Mean Absolute Error", mean_absolute_error(ytest,pred_test))
# Out:
# Mean Squared error 33.50756531501423
# Mean Absolute Error 4.398832508673861

# %% [markdown]
# # Using Grid search CV to check best Parameter

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge, Lasso

ridge_params = {'alpha':[0.00001,0.0001, 0.001, 0.1, 2,1,3,5,10,20]}
xg_grid = GridSearchCV(Ridge(), ridge_params, cv=3)
xg_grid.fit(xtrain, ytrain)
print('Best score:', xg_grid.best_score_)
print('Best score:', xg_grid.best_params_)
print('Best score:', xg_grid.best_estimator_)
# Out:
# Best score: 0.6099318869478145
# Best score: {'alpha': 20}
# Best score: Ridge(alpha=20)

# %% [markdown]
# As per grid search cv we found the best parameter is 20 in Ridge Regression

# %% [markdown]
# # Chossing the best model

# %%
from sklearn.linear_model import Ridge
rid = Ridge(alpha= 20)
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size= 0.22, random_state=27)
rid.fit(xtrain,ytrain)
pred_train =rid.predict(xtrain)
pred_test= rid.predict(xtest)
print("Mean Squared error", mean_squared_error(ytest,pred_test))
print("Mean Absolute Error", mean_absolute_error(ytest,pred_test))
# Out:
# Mean Squared error 3.866288228322652
# Mean Absolute Error 1.795349051053222

# %% [markdown]
# # Finding the R2 Score

# %%
print(r2_score(ytest,pred_test))
# Out:
# 0.9519167200030939

# %% [markdown]
# # Cross Validation of the Model

# %%
train_accuracy = r2_score(ytrain,pred_train)
test_accuracy =r2_score(ytest,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score =cross_val_score(rid,x,y,cv=j)
    cv_mean = cv_score.mean()
    print(f"At cross val  {j} the cv score  is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross val  2 the cv score  is 0.17476915100640517 and accuracy score for training is 0.7804041218527197 and accuracy for testing is 0.9519167200030939
#
#
# At cross val  3 the cv score  is 0.49711801417127005 and accuracy score for training is 0.7804041218527197 and accuracy for testing is 0.9519167200030939
#
#
# At cross val  4 the cv score  is 0.5789513056444797 and accuracy score for training is 0.7804041218527197 and accuracy for testing is 0.9519167200030939
#
#
# At cross val  5 the cv score  is 0.17703760139809685 and accuracy score for training is 0.7804041218527197 and accuracy for testing is 0.9519167200030939
#
#
# At cross val  6 the cv score  is 0.4187697153465404 and accuracy score for training is 0.7804041218527197 and accuracy for testing is 0.9519167200030939
#
#
# At cross val  7 the cv score  is 0.28752796505169276 and accuracy score for training is 0.7804041218527197 and accuracy for testing is 0.9519167200030939
#
#
# ...

# %%
from sklearn.model_selection import cross_val_score
for i in range (2,10):
    score= cross_val_score(rid,x,y,cv=i)
    print("At cv value at", i,"the cv score is",score)
    print(score.mean())
    print(score.std())
# Out:
# At cv value at 2 the cv score is [0.05651347 0.29302483]
# 0.17476915100640517
# 0.11825568234441369
# At cv value at 3 the cv score is [0.10037899 0.54753892 0.84343613]
# 0.49711801417127005
# 0.30543976970344233
# At cv value at 4 the cv score is [0.14472867 0.64780499 0.67903657 0.84423499]
# 0.5789513056444797
# 0.2615734191300797
# At cv value at 5 the cv score is [ 0.30810003 -1.16405467  0.47677992  0.33526596  0.92909677]
# 0.17703760139809685
# 0.7065664170980994
# At cv value at 6 the cv score is [ 0.33949099 -0.52494632  0.37587052  0.57743901  0.77027339  0.97449071]
# 0.4187697153465404
# 0.4754440053948828
# At cv value at 7 the cv score is [ 0.33949099 -0.52494632 -0.49546177  0.37042087  0.57127607  0.80628727
#   0.94562864]
# 0.28752796505169276
# 0.5432020779390148
# At cv value at 8 the cv score is [ 0.12516138  0.22115269 -1.24853821  0.77576327  0.6478116   0.78200653
#   0.93200212  0.88489963]
# 0.3900323752341141
# 0.6792548817023958
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(x= ytest, y =pred_test, color= "maroon")
plt.plot(ytest,ytest, color='b')
plt.xlabel('Actual Charges', fontsize= 14)
plt.ylabel("Predicted Charges", fontsize=14)
plt.show()

# %% [markdown]
# # Saving Model

# %%
import pickle
filename = 'baceball.pkl'
pickle.dump(rid, open(filename, 'wb'))

# %% [markdown]
# # Conclusion

# %%
loaded_model = pickle.load(open('baceball.pkl', 'rb'))
result = loaded_model.score(xtest,ytest)
print(result)
# Out:
# 0.9519167200030939

# %%
conclusion = pd.DataFrame([loaded_model.predict(xtest)[:],pred_test[:]],index=["Predicted", "Original"])

# %%
conclusion
# Out:
#                    0         1          2          3          4          5  \
# Predicted  66.049811  97.62621  87.649728  78.637045  85.732311  80.354424
# Original   66.049811  97.62621  87.649728  78.637045  85.732311  80.354424
#
#                    6
# Predicted  78.144045
# Original   78.144045
