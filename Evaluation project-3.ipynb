# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("C:\\Users\\NITIN GUPTA\\avocado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.head(10).T
# Out:
#                          0             1             2             3  \
# Unnamed: 0               0             1             2             3
# Date            2015-12-27    2015-12-20    2015-12-13    2015-12-06
# AveragePrice          1.33          1.35          0.93          1.08
# Total Volume      64236.62      54876.98     118220.22      78992.15
# 4046               1036.74        674.28         794.7        1132.0
# 4225              54454.85      44638.81     109149.67      71976.41
# 4770                 48.16         58.33         130.5         72.58
# Total Bags         8696.87       9505.56       8145.35       5811.16
# Small Bags         8603.62       9408.07       8042.21        5677.4
# Large Bags           93.25         97.49        103.14        133.76
# XLarge Bags            0.0           0.0           0.0           0.0
# type          conventional  conventional  conventional  conventional
# year                  2015          2015          2015          2015
# ...

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per above visualization there is no Null Values

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# We have seen in datatypes Date, Type and region has object datatypes , and 11 columns has numerical values

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# Unnamed: 0 is the column for indexing so drop this column

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.drop(['Unnamed: 0'], axis = 1, inplace= True)

# %%
df.shape
# Out:
# (18249, 13)

# %% [markdown]
# # Changing Date in Date Datatype as it is in Object type

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].apply(lambda x:x.month)
df['Day']=df['Date'].apply(lambda x:x.day)

# %%
df
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0     2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1     2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2     2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3     2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4     2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# Month                    int64
# Day                      int64
# dtype: object

# %% [markdown]
# Now Date is changed in Date Data Type

# %%
sns.countplot(x = "type", data= df)
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# As per observation the 9126 are Conventional type and 9123 are Organic Type

# %%
sns.countplot(x = "region", data= df)
df['region'].value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %% [markdown]
# As per above visualization the region divided as per survay taken

# %% [markdown]
# # Check the distribution of average price

# %%
sns.distplot(a=df['AveragePrice'], kde=False)
# Out:
# <AxesSubplot:xlabel='AveragePrice'>

# %% [markdown]
# Aas per the above visualization the price of avocado in mostly 1.0 to 1.5

# %%
for i in df:
    plt.figure(figsize=(50,50))
    sns.barplot(y = df[i], x = df['AveragePrice'])
    plt.show()

# %% [markdown]
# As per above visualization we can see the avecado price is hike in month of 8-10, The price is very high for reagions Harthford Springfield, SanFransisco, New York, Phildelphia and Scarmento and most average price in year 2017 to  2018

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# Month             0.162409     -0.024689 -0.025803 -0.022108 -0.033424
# Day               0.027386     -0.009747 -0.010159 -0.012393 -0.009009
#
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot= True, fmt= '0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per the above visualization all the feature columns are not coorelated with Average Price, So we can do some feature engineering on catagorical datatype

# %%
df['region'].nunique()
# Out:
# 54

# %%
df['type'].nunique()
# Out:
# 2

# %% [markdown]
# As per above region and type there are 2 types distributed among all 54 region and we have seperate Date, Month Year columns so we can drop Type and date column

# %%
df.drop(['region','Date'],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
# 5          1.26      55979.78  1184.27   48067.99   43.61     6683.91
# 6          0.99      83453.76  1368.92   73672.72   93.26     8318.86
# 7          0.98     109428.33   703.75  101815.36   80.00     6829.22
# 8          1.02      99811.42  1022.15   87315.57   85.34    11388.36
# 9          1.07      74338.76   842.40   64757.44  113.00     8625.92
#
#    Small Bags  Large Bags  XLarge Bags          type  year  Month  Day
# 0     8603.62       93.25          0.0  conventional  2015     12   27
# ...

# %% [markdown]
# # Change the type through label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i]= enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  Month  Day
# ...

# %% [markdown]
# # Checking Skewness

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# Month            0.106617
# Day              0.014310
# dtype: float64

# %% [markdown]
# Skewness mor than +/-0.5 will be treated
#
# we will remove skewness from numerical data

# %%
df.hist(figsize= (30,40), bins =100, xlabelsize = 10, ylabelsize = 10)
plt.show()

# %% [markdown]
# As per above visualization skewness is present in data

# %% [markdown]
# # Removing Skewness Using Power Transformation

# %%
from sklearn.preprocessing import power_transform

df[['Total Volume','4046','4225','4770', 'Total Bags', 'Small Bags','Large Bags', 'XLarge Bags']]=power_transform(df[['Total Volume','4046','4225','4770', 'Total Bags', 'Small Bags','Large Bags', 'XLarge Bags']],method='yeo-johnson')

# %%
df.skew()
# Out:
# AveragePrice    0.580303
# Total Volume    0.011171
# 4046           -0.022679
# 4225           -0.017740
# 4770            0.032184
# Total Bags     -0.001626
# Small Bags      0.007058
# Large Bags     -0.073809
# XLarge Bags     0.793520
# type            0.000329
# year            0.215339
# Month           0.106617
# Day             0.014310
# dtype: float64

# %% [markdown]
# # Checking for Outliers

# %%
for i in df:
    plt.boxplot(df[i], labels= [i])
    plt.show()

# %% [markdown]
# As per observation Most of Outliers Present in Target Column Average Price and 4225, Total Bags, small Bags & Large Bags has less outliers

# %% [markdown]
# # IQR method to Remove Outliers

# %%
from scipy import stats

IQR = stats.iqr(df)
IQR
# Out:
# 2.152875786774941

# %%
Q1 = df.quantile()
Q3 = df.quantile()
df_out = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
print(df_out.shape)
# Out:
# (2370, 13)

# %% [markdown]
# There is huge Data loss so ot using this method

# %% [markdown]
# # ZScore Method

# %%
from scipy.stats import zscore

z = np.abs(zscore(df))
print(np.where(z>3))
# Out:
# (array([ 2699,  5462,  5475,  5476,  5477,  5478,  5479,  5480,  5481,
#         5482,  5483,  5484,  5485,  5486,  5487,  5488,  5489,  5490,
#         5491,  5492,  5493,  5494,  5495,  5496,  5497,  5506,  5506,
#         8319,  8322,  8344,  8344,  8345,  8345,  8346,  8346,  8347,
#         8347,  8348,  8348,  8349,  8349,  8350,  8351,  8352,  8352,
#         8353,  8353,  8354,  8354,  8355,  8356,  8357,  8358,  8359,
#         8360,  8361,  8362,  8363,  8364,  8365,  8365,  8366,  8366,
#         8366,  8367,  8367,  8368,  8369,  8370,  8371,  9090,  9090,
#         9091,  9091,  9092,  9092,  9093,  9093,  9094,  9094,  9095,
#         9096,  9096,  9097,  9097,  9097,  9097,  9098,  9098,  9099,
#         9099,  9100,  9101,  9212,  9894, 10381, 11024, 11320, 11320,
#        11321, 11321, 11322, 11323, 11324, 11325, 11325, 11326, 11326,
#        11327, 11328, 11329, 11330, 11331, 11332, 11332, 11333, 11336,
# ...

# %%
df_new = df[(z<3).all(axis=1)]
print("with outliers::",df.shape)
print("After removing outliers::",df_new.shape)
# Out:
# with outliers:: (18249, 13)
# After removing outliers:: (18025, 13)

# %%
print("Total Data Loss", ((18249-18025)/18249)*100)
# Out:
# Total Data Loss 1.2274645186037592

# %% [markdown]
# We are using Zscore method for outlier removal

# %% [markdown]
# # Splitting Data in  Training and Testing

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
x= df_new.iloc[:,1:]
y= df_new.iloc[:,0]

# %%
x.shape
# Out:
# (18025, 12)

# %%
y.shape
# Out:
# (18025,)

# %% [markdown]
# # Importing the Model

# %%
import sklearn
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge, Lasso

# %%
ne = KNeighborsRegressor(n_neighbors=2)
dt = DecisionTreeRegressor()
rf= RandomForestRegressor(n_estimators=100, random_state=42)
ab= AdaBoostRegressor()
rd= Ridge()
mod = [ne, dt, rf, ab, rd]
mod
# Out:
# [KNeighborsRegressor(n_neighbors=2),
#  DecisionTreeRegressor(),
#  RandomForestRegressor(random_state=42),
#  AdaBoostRegressor(),
#  Ridge()]

# %%
for j in mod:
    for i in range(0,100):
        xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size= 0.22, random_state=i)
        j.fit(xtrain,ytrain)
        pred_train = j.predict(xtrain)
        pred_test= j.predict(xtest)

        print(f"For Model {j} At random state {i}, the training accuracy is: {r2_score(ytrain,pred_train)}")
        print(f"For Model {j} At random state {i}, the testing accuracy is: {r2_score(ytest,pred_test)}")
        print('\n')
# Out:
# For Model KNeighborsRegressor(n_neighbors=2) At random state 0, the training accuracy is: 0.8671660633562664
# For Model KNeighborsRegressor(n_neighbors=2) At random state 0, the testing accuracy is: 0.5420503842968328
#
#
# For Model KNeighborsRegressor(n_neighbors=2) At random state 1, the training accuracy is: 0.8636224385969412
# For Model KNeighborsRegressor(n_neighbors=2) At random state 1, the testing accuracy is: 0.5785287995214876
#
#
# For Model KNeighborsRegressor(n_neighbors=2) At random state 2, the training accuracy is: 0.8661985321351783
# For Model KNeighborsRegressor(n_neighbors=2) At random state 2, the testing accuracy is: 0.5673063156959387
#
#
# For Model KNeighborsRegressor(n_neighbors=2) At random state 3, the training accuracy is: 0.8637302236204343
# For Model KNeighborsRegressor(n_neighbors=2) At random state 3, the testing accuracy is: 0.5796146340058415
#
#
# ...

# %% [markdown]
# As per above visualization we found model Random Forest Regressor is best at random state 45

# %%
print("Mean Squared error", mean_squared_error(ytest,pred_test))
print("Mean Absolute Error", mean_absolute_error(ytest,pred_test))
# Out:
# Mean Squared error 0.06671906318694797
# Mean Absolute Error 0.20418210677447654

# %% [markdown]
# # Using Grid Search CV to find the best parameter

# %%
from sklearn.model_selection import GridSearchCV

model = RandomForestRegressor()
param_grid = {'n_estimators': [10,20,50,100], 'random_state' : [42]}
xg_grid = GridSearchCV(estimator = model, param_grid = param_grid)
print(xg_grid)
xg_grid.fit(xtrain, ytrain)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'n_estimators': [10, 20, 50, 100],
#                          'random_state': [42]})
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'n_estimators': [10, 20, 50, 100],
#                          'random_state': [42]})

# %%
print(xg_grid.best_score_)
print(xg_grid.best_estimator_)
print(xg_grid.best_params_)
# Out:
# 0.8556333552862927
# RandomForestRegressor(random_state=42)
# {'n_estimators': 100, 'random_state': 42}

# %% [markdown]
# As per Grid Search CV we found the best accuracy when n_estimators=100, random_state= 42

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size= 0.22, random_state=42)
RFR = RandomForestRegressor(n_estimators=100)
RFR.fit(xtrain,ytrain)
pred_train =RFR.predict(xtrain)
pred_test= RFR.predict(xtest)
print("Mean Squared error", mean_squared_error(ytest,pred_test))
print("Mean Absolute Error", mean_absolute_error(ytest,pred_test))
# Out:
# Mean Squared error 0.019358078103883007
# Mean Absolute Error 0.09691326273323246

# %%
print(r2_score(ytest,pred_test))
# Out:
# 0.8698312575344872

# %% [markdown]
# # Cross Validation of the Model

# %%
train_accuracy = r2_score(ytrain,pred_train)
test_accuracy =r2_score(ytest,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score =cross_val_score(RFR,x,y,cv=j)
    cv_mean = cv_score.mean()
    print(f"At cross val  {j} the cv score  is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross val  2 the cv score  is -1.6057087215797998 and accuracy score for training is 0.9813628651019 and accuracy for testing is 0.8698312575344872
#
#
# At cross val  3 the cv score  is -0.10125076020206021 and accuracy score for training is 0.9813628651019 and accuracy for testing is 0.8698312575344872
#
#
# At cross val  4 the cv score  is 0.06761349827629728 and accuracy score for training is 0.9813628651019 and accuracy for testing is 0.8698312575344872
#
#
# At cross val  5 the cv score  is 0.20304395328653962 and accuracy score for training is 0.9813628651019 and accuracy for testing is 0.8698312575344872
#
#
# At cross val  6 the cv score  is 0.1227875558241374 and accuracy score for training is 0.9813628651019 and accuracy for testing is 0.8698312575344872
#
#
# At cross val  7 the cv score  is 0.2950052279484253 and accuracy score for training is 0.9813628651019 and accuracy for testing is 0.8698312575344872
#
#
# ...

# %%
from sklearn.model_selection import cross_val_score
for i in range (2,10):
    score= cross_val_score(RFR,x,y,cv=i)
    print("At cv value at", i,"the cv score is",score)
    print(score.mean())
    print(score.std())
# Out:
# At cv value at 2 the cv score is [-2.20145468 -0.869172  ]
# -1.5353133402375345
# 0.6661413368434022
# At cv value at 3 the cv score is [-0.84329609  0.43361978  0.12663173]
# -0.09434819255668055
# 0.5442135783835852
# At cv value at 4 the cv score is [-0.07655721  0.19814607  0.11398926  0.03598664]
# 0.06789118894184482
# 0.10121092746740148
# At cv value at 5 the cv score is [-0.29586842  0.41335863  0.60723792  0.30050365 -0.02572509]
# 0.19990133497772705
# 0.3219636219174173
# At cv value at 6 the cv score is [-0.71196176  0.48258436  0.32163203  0.08194365  0.40363849  0.20129111]
# 0.12985464530109828
# 0.39837333972397865
# At cv value at 7 the cv score is [-0.26504355  0.1840458   0.56794572  0.62880368  0.32595283  0.43591071
#   0.18047885]
# 0.2940134330250311
# 0.2792351947497799
# At cv value at 8 the cv score is [0.01936476 0.39992327 0.56151104 0.30849441 0.28308213 0.38841114
#  0.42232708 0.18062016]
# 0.3204667477977447
# 0.15458334455851966
# ...

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()

# %%
for i in range(0,10):
    xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size= 0.22, random_state=i)
    lr.fit(xtrain,ytrain)
    pred_train = lr.predict(xtrain)
    pred_test= lr.predict(xtest)

    print(f"For Model {lr} At random state {i}, the training accuracy is: {r2_score(ytrain,pred_train)}")
    print(f"For Model {lr} At random state {i}, the testing accuracy is: {r2_score(ytest,pred_test)}")
    print('\n')
# Out:
# For Model LinearRegression() At random state 0, the training accuracy is: 0.5715991628733539
# For Model LinearRegression() At random state 0, the testing accuracy is: 0.551532432650905
#
#
# For Model LinearRegression() At random state 1, the training accuracy is: 0.5641204948027186
# For Model LinearRegression() At random state 1, the testing accuracy is: 0.5784522097259406
#
#
# For Model LinearRegression() At random state 2, the training accuracy is: 0.5702169106232325
# For Model LinearRegression() At random state 2, the testing accuracy is: 0.5573879405046264
#
#
# For Model LinearRegression() At random state 3, the training accuracy is: 0.5678238212272595
# For Model LinearRegression() At random state 3, the testing accuracy is: 0.565774186857848
#
#
# For Model LinearRegression() At random state 4, the training accuracy is: 0.5657657497745588
# For Model LinearRegression() At random state 4, the testing accuracy is: 0.5725051479659993
#
#
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(x= ytest, y =pred_test, color= "maroon")
plt.plot(ytest,ytest, color='b')
plt.xlabel('Actual Charges', fontsize= 14)
plt.ylabel("Predicted Charges", fontsize=14)
plt.show()

# %% [markdown]
# # Saving Model

# %%
import pickle
filename = 'avocado.pkl'
pickle.dump(RFR, open(filename, 'wb'))

# %% [markdown]
# # Conclusion

# %%
loaded_model = pickle.load(open('avocado.pkl', 'rb'))
result = loaded_model.score(xtest,ytest)
print(result)
# Out:
# 0.8698312575344872

# %%
conclusion = pd.DataFrame([loaded_model.predict(xtest)[:],pred_test[:]],index=["Predicted", "Original"])

# %%
conclusion
# Out:
#                0        1         2         3         4         5     \
# Predicted  1.039600  1.18270  1.077100  1.346100  0.776500  1.632500
# Original   1.273835  1.51301  1.436394  1.269777  1.563445  1.022239
#
#                6         7         8         9     ...      3956      3957  \
# Predicted  1.314800  1.663500  1.426300  1.356700  ...  1.829300  1.958200
# Original   1.808639  1.323251  1.466847  1.995261  ...  1.761361  1.848818
#
#                3958      3959      3960     3961     3962      3963      3964  \
# Predicted  1.581900  0.896300  1.003200  1.26170  1.72530  1.104500  1.701800
# Original   1.778871  1.071646  1.018567  1.20109  1.11058  1.410174  1.081789
#
#                3965
# Predicted  1.506900
# Original   1.290689
#
# [2 rows x 3966 columns]

# %% [markdown]
# # Classification Method

# %%
df
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0              1.33     -0.094167 -0.660667  0.300522 -0.246071   -0.528331
# 1              1.35     -0.163138 -0.778196  0.224457 -0.199829   -0.490503
# 2              0.93      0.171997 -0.733558  0.574906 -0.005791   -0.556123
# 3              1.08     -0.003767 -0.636385  0.409041 -0.147079   -0.698279
# 4              1.28     -0.194924 -0.687187  0.217585 -0.136671   -0.672238
# ...             ...           ...       ...       ...       ...         ...
# 18244          1.63     -0.678228 -0.470376 -0.920043 -1.239006   -0.340035
# 18245          1.71     -0.770128 -0.622146 -0.669147 -1.239006   -0.501429
# 18246          1.87     -0.774035 -0.622095 -0.775016  0.402587   -0.495528
# 18247          1.93     -0.701459 -0.552907 -0.713806  0.402287   -0.429290
# 18248          1.62     -0.667567 -0.371308 -0.787535  0.124177   -0.390245
#
# ...

# %% [markdown]
# # Splittiin fearure & Target

# %%
x = df.drop('type', axis=1)
y = df['type']

# %% [markdown]
# # Scaling thr data using min max scaler

# %%
from sklearn .preprocessing import MinMaxScaler
msn = MinMaxScaler()
x= msn.fit_transform(x)

# %%
df['type'].value_counts()
# Out:
# 0    9126
# 1    9123
# Name: type, dtype: int64

# %% [markdown]
# # Importing Model

# %%
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier

# %%
LR = LogisticRegression()
KNN = KNeighborsClassifier()
SV = SVC()
DT = DecisionTreeClassifier()
RF = RandomForestClassifier(n_estimators=100, random_state=42)
mod = [LR, KNN, SV, DT, RF]

mod
# Out:
# [LogisticRegression(),
#  KNeighborsClassifier(),
#  SVC(),
#  DecisionTreeClassifier(),
#  RandomForestClassifier(random_state=42)]

# %%
for i in mod:
    xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size= .22, random_state=42)
    i.fit(xtrain,ytrain)
    pred = i.predict(xtest)
    print("Accuracy Score", accuracy_score(ytest,pred))
    print("Confusion Metrics", confusion_matrix(ytest,pred))
    print("Classification_report", classification_report(ytest,pred))
# Out:
# Accuracy Score 0.9628891656288917
# Confusion Metrics [[1919   80]
#  [  69 1947]]
# Classification_report               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      1999
#            1       0.96      0.97      0.96      2016
#
#     accuracy                           0.96      4015
#    macro avg       0.96      0.96      0.96      4015
# weighted avg       0.96      0.96      0.96      4015
#
# Accuracy Score 0.9858032378580324
# Confusion Metrics [[1979   20]
#  [  37 1979]]
# Classification_report               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1999
#            1       0.99      0.98      0.99      2016
#
#     accuracy                           0.99      4015
#    macro avg       0.99      0.99      0.99      4015
# weighted avg       0.99      0.99      0.99      4015
#
# Accuracy Score 0.9877957658779577
# Confusion Metrics [[1972   27]
#  [  22 1994]]
# ...

# %% [markdown]
# As per all the above classification techniques Random forest gives the better accuracy out of all classifiers

# %% [markdown]
# # Checking With different parameter using Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
model = RandomForestClassifier()
param_grid = {'n_estimators': [200, 500],'criterion' :['gini', 'entropy']}

# %%
grid = GridSearchCV(estimator = model, param_grid = param_grid)
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'n_estimators': [200, 500]})

# %%
print(grid.best_score_)
print(grid.best_estimator_)
print(grid.best_params_)
# Out:
# 0.9939583060271554
# RandomForestClassifier(criterion='entropy', n_estimators=500)
# {'criterion': 'entropy', 'n_estimators': 500}

# %% [markdown]
# As per Grid Search CV we found the best accuracy when criterion='entropy',n_estimators=500

# %%
RFC = RandomForestClassifier(criterion='entropy',n_estimators=500)

# %%
RFC.fit(xtrain,ytrain)
pred = RFC.predict(xtest)
print("Accuracy Score", accuracy_score(ytest,pred))
print("Confusion Metrics", confusion_matrix(ytest,pred))
print("Classification_report", classification_report(ytest,pred))
# Out:
# Accuracy Score 0.9972602739726028
# Confusion Metrics [[1994    5]
#  [   6 2010]]
# Classification_report               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1999
#            1       1.00      1.00      1.00      2016
#
#     accuracy                           1.00      4015
#    macro avg       1.00      1.00      1.00      4015
# weighted avg       1.00      1.00      1.00      4015

# %% [markdown]
# # Cross validation score for Random Forest Classifier

# %%
from sklearn.model_selection import cross_val_score
for i in range (2,10):
    score= cross_val_score(RFC,x,y,cv=i)
    print("At cv value at", i,"the cv score is",score)
    print(score.mean())
    print(score.std())
# Out:
# At cv value at 2 the cv score is [0.97939726 0.95933801]
# 0.9693676349594326
# 0.010029625314539992
# At cv value at 3 the cv score is [0.97862897 0.97977971 0.96925859]
# 0.9758890898131405
# 0.0047119497674844215
# At cv value at 4 the cv score is [0.9947403  0.96953091 0.98246383 0.95155633]
# 0.9745728441307304
# 0.016001366181846437
# At cv value at 5 the cv score is [0.99315068 0.96739726 0.98767123 0.98082192 0.95560428]
# 0.9769290742068572
# 0.013706140161422364
# At cv value at 6 the cv score is [0.99079553 0.96844181 0.9852071  0.9740217  0.98947715 0.94804341]
# 0.9759977833802234
# 0.014876842979848587
# At cv value at 7 the cv score is [0.99347909 0.98734177 0.96355965 0.9911776  0.97429996 0.99079402
#  0.9401611 ]
# 0.9772590278919393
# 0.018183036964720647
# At cv value at 8 the cv score is [0.99342682 0.99473915 0.95396756 0.98640947 0.96975011 0.98903989
#  0.9894783  0.93555458]
# 0.9765457350493982
# 0.02022637229502213
# ...

# %% [markdown]
# # AUC ROC CURVE

# %%
from sklearn.metrics import roc_curve,auc
fpr,tpr,thresholds = roc_curve(pred, ytest)
roc_auc=auc(fpr,tpr)

plt.figure()
plt.plot(fpr, tpr, color = "darkorange", lw =10, label ="ROC Curve (area= %0.2f)" %roc_auc)
plt.plot([0,1], [0,1], color= 'navy', lw =10, linestyle ='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristics")
plt.legend(loc ="lower right")
plt.show()

# %% [markdown]
# # Model Saving

# %%
import pickle
filename = "avocedo_c.pkl"
pickle.dump(RF, open(filename, 'wb'))

# %% [markdown]
# # Conclusion

# %%
import numpy as np
a = np.array(ytest)
predicted =np.array(RFC.predict(xtrain))
df_com= pd.DataFrame({"Original":a, "Predicted":pred}, index =range(len(a)))
df_com
# Out:
#       Original  Predicted
# 0            0          0
# 1            0          0
# 2            1          1
# 3            0          0
# 4            1          1
# ...        ...        ...
# 4010         0          0
# 4011         0          0
# 4012         1          1
# 4013         0          0
# 4014         1          1
#
# [4015 rows x 2 columns]
